# %% [raw]
# 1. Data cleaning
# 2. EDA
# 3. Text preprocessing
# 4. Model Building
# 5. Evaluation
# 6. Improvement
# 7. Website
# 8. Deploy

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('spam.csv',encoding='ISO-8859-1')
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
df.isnull().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %%
df=df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],axis=1)

# %%
df.rename(columns={'v1':'target','v2':'text'},inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['target']=le.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df[df.duplicated()]
# Out:
#       target                                               text
# 102        0  As per your request 'Melle Melle (Oru Minnamin...
# 153        0  As per your request 'Melle Melle (Oru Minnamin...
# 206        0  As I entered my cabin my PA said, '' Happy B'd...
# 222        0                             Sorry, I'll call later
# 325        0                   No calls..messages..missed calls
# ...      ...                                                ...
# 5524       1  You are awarded a SiPix Digital Camera! call 0...
# 5535       0  I know you are thinkin malaria. But relax, chi...
# 5539       0                         Just sleeping..and surfing
# 5553       0                        Hahaha..use your brain dear
# 5558       0                             Sorry, I'll call later
#
# [403 rows x 2 columns]

# %%
df=df.drop_duplicates(keep='first')

# %% [markdown]
# # EDA

# %%
df['target'].value_counts()/df.shape[0]
# Out:
# target
# 0    0.87367
# 1    0.12633
# Name: count, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.pie(x=df['target'].value_counts(),labels=['ham','spam'],autopct='%0.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x1c42f8792b0>,
# ...
#  [Text(-1.0144997251399075, 0.4251944351600247, 'ham'),
#   Text(1.014499764949479, -0.4251943401757036, 'spam')],
#  [Text(-0.5533634864399495, 0.23192423736001344, '87.37'),
#   Text(0.5533635081542612, -0.23192418555038377, '12.63')])

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['text']
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5567    This is the 2nd time we have tried 2 contact u...
# 5568                Will Ì_ b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: text, Length: 5169, dtype: object

# %%
df['character']=df['text'].apply(len)
df
# Out:
#       target                                               text  character
# 0          0  Go until jurong point, crazy.. Available only ...        111
# 1          0                      Ok lar... Joking wif u oni...         29
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...        155
# 3          0  U dun say so early hor... U c already then say...         49
# 4          0  Nah I don't think he goes to usf, he lives aro...         61
# ...      ...                                                ...        ...
# 5567       1  This is the 2nd time we have tried 2 contact u...        161
# 5568       0              Will Ì_ b going to esplanade fr home?         37
# 5569       0  Pity, * was in mood for that. So...any other s...         57
# 5570       0  The guy did some bitching but I acted like i'd...        125
# 5571       0                         Rofl. Its true to its name         26
#
# [5169 rows x 3 columns]

# %%
df['words']=df['text'].apply(lambda x: len(nltk.word_tokenize(x)))

# %%
df['sentences']=df['text'].apply(lambda x: len(nltk.sent_tokenize(x)))

# %%
df
# Out:
#       target                                               text  character  \
# 0          0  Go until jurong point, crazy.. Available only ...        111
# 1          0                      Ok lar... Joking wif u oni...         29
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...        155
# 3          0  U dun say so early hor... U c already then say...         49
# 4          0  Nah I don't think he goes to usf, he lives aro...         61
# ...      ...                                                ...        ...
# 5567       1  This is the 2nd time we have tried 2 contact u...        161
# 5568       0              Will Ì_ b going to esplanade fr home?         37
# 5569       0  Pity, * was in mood for that. So...any other s...         57
# 5570       0  The guy did some bitching but I acted like i'd...        125
# 5571       0                         Rofl. Its true to its name         26
#
#       words  sentences
# 0        24          2
# ...

# %%
plt.bar(df['target'],df['character'],color=['green', 'orange'])
# Out:
# <BarContainer object of 5169 artists>

# %%
df.columns
# Out:
# Index(['target', 'text', 'character', 'words', 'sentences'], dtype='object')

# %%
df[df['target']==0][['character', 'words', 'sentences']].describe()
# Out:
#          character        words    sentences
# count  4516.000000  4516.000000  4516.000000
# mean     70.459256    17.123782     1.820195
# std      56.358207    13.493970     1.383657
# min       2.000000     1.000000     1.000000
# 25%      34.000000     8.000000     1.000000
# 50%      52.000000    13.000000     1.000000
# 75%      90.000000    22.000000     2.000000
# max     910.000000   220.000000    38.000000

# %%
df[df['target']==1][['character', 'words', 'sentences']].describe()
# Out:
#         character       words   sentences
# count  653.000000  653.000000  653.000000
# mean   137.891271   27.667688    2.970904
# std     30.137753    7.008418    1.488425
# min     13.000000    2.000000    1.000000
# 25%    132.000000   25.000000    2.000000
# 50%    149.000000   29.000000    3.000000
# 75%    157.000000   32.000000    4.000000
# max    224.000000   46.000000    9.000000

# %%
plt.figure(figsize=(10,6))
sns.histplot(df[df['target']==0]['character'])
sns.histplot(df[df['target']==1]['character'],color='red')
# Out:
# <Axes: xlabel='character', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))

sns.histplot(df[df['target']==0]['words'])
sns.histplot(df[df['target']==1]['words'],color='red')
# Out:
# <Axes: xlabel='words', ylabel='Count'>

# %%
mean_char=df.groupby('target')['character'].mean().reset_index()
mean_char
# Out:
#    target   character
# 0       0   70.459256
# 1       1  137.891271

# %%
df.groupby('target')['words'].mean().reset_index()
# Out:
#    target      words
# 0       0  17.123782
# 1       1  27.667688

# %%
sns.pairplot(df,hue='target')

# %%
df.columns
# Out:
# Index(['target', 'text', 'character', 'words', 'sentences'], dtype='object')

# %%
selected_columns = ['target', 'character', 'words', 'sentences']
numeric_df = df[selected_columns]
sns.heatmap(numeric_df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # we keep the character column because it has the hieghest correlation with target. and also the other columns are highly correalted

# %% [markdown]
# # preprocessing of the textual data
#  1) lower case
#  2) tokenization
#  3) removing the special character
#  4) remove the stop words
#  5)  stemming

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
def transform_text(text):
    text=text.lower()
    text=nltk.word_tokenize(text)

    y=[]
    for i in text:
        if i.isalnum():
            y.append(i)
    text=y[:]
    y.clear()

    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)

    text=y[:]
    y.clear()
    for i in text:
        y.append(ps.stem(i))
        
    return " ".join(y)

# %%
transform_text('Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...')
# Out:
# 'go jurong point crazi avail bugi n great world la e buffet cine got amor wat'

# %%
df['text'][0]
# Out:
# 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'

# %%
df['transformed_text']=df['text'].apply(transform_text)

# %%
from wordcloud import WordCloud

# %%
wc=WordCloud(width=500,height=500,min_font_size=10,background_color='white')
spam_wc=wc.generate(df[df['target']==1]['transformed_text'].str.cat(sep=" "))
plt.imshow(spam_wc)

# %%
wc=WordCloud(width=500,height=500,min_font_size=10,background_color='white')
ham_wc=wc.generate(df[df['target']==0]['transformed_text'].str.cat(sep=" "))
plt.imshow(ham_wc)

# %%
df
# Out:
#       target                                               text  character  \
# 0          0  Go until jurong point, crazy.. Available only ...        111
# 1          0                      Ok lar... Joking wif u oni...         29
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...        155
# 3          0  U dun say so early hor... U c already then say...         49
# 4          0  Nah I don't think he goes to usf, he lives aro...         61
# ...      ...                                                ...        ...
# 5567       1  This is the 2nd time we have tried 2 contact u...        161
# 5568       0              Will Ì_ b going to esplanade fr home?         37
# 5569       0  Pity, * was in mood for that. So...any other s...         57
# 5570       0  The guy did some bitching but I acted like i'd...        125
# 5571       0                         Rofl. Its true to its name         26
#
# ...

# %%
spam_words=[]
for msg in df[df['target']==1]['transformed_text'].tolist():
    for word in msg.split():
        spam_words.append(word)

# %%
len(spam_words)
# Out:
# 9939

# %%
from collections import Counter

# %%
most_common_spam_df=pd.DataFrame(Counter(spam_words).most_common(50),columns=['most_words','count'])
most_common_spam_df
# Out:
#    most_words  count
# 0        call    320
# 1        free    191
# 2           2    155
# 3         txt    141
# 4        text    122
# 5           u    119
# 6          ur    119
# 7       mobil    114
# 8        stop    104
# 9       repli    103
# 10      claim     98
# 11          4     97
# 12      prize     82
# 13        get     74
# 14        new     64
# 15     servic     64
# 16       tone     63
# 17       send     60
# 18     urgent     57
# 19      nokia     57
# 20    contact     56
# 21      award     55
# 22      phone     52
# 23       cash     51
# 24      pleas     51
# 25       week     49
# 26        win     48
# 27          c     45
# 28    collect     45
# 29        min     45
# 30     custom     42
# 31     messag     42
# 32   guarante     42
# 33        per     41
# 34       chat     38
# 35        tri     37
# 36        msg     35
# 37       draw     35
# 38     number     35
# 39         cs     35
# 40       show     33
# 41      today     33
# ...

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=most_common_spam_df['most_words'],y=most_common_spam_df['count'],hue=most_common_spam_df['most_words'],data=most_common_spam_df,palette='rocket')
plt.xticks(rotation='vertical')
plt.show()

# %%
ham_words=[]
for ham in df[df['target']==0]['transformed_text'].tolist():
    for word in ham.split():
        ham_words.append(word)

# %%
len(ham_words)
# Out:
# 35404

# %%
plt.figure(figsize=(12,6))
plt.bar(pd.DataFrame(Counter(ham_words).most_common(50))[0],pd.DataFrame(Counter(ham_words).most_common(50))[1])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# # Model Building

# %% [markdown]
# # here using the count vectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()
x=cv.fit_transform(df['transformed_text']).toarray()

# %%
x.shape
# Out:
# (5169, 6708)

# %%
y=df['target'].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y ,test_size=0.2,random_state=42)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB()

# %%
gnb.fit(x_train,y_train)
y_pred1=gnb.predict(x_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8684719535783365
# [[772 117]
#  [ 19 126]]
# 0.5185185185185185

# %%
mnb.fit(x_train,y_train)
y_pred2=mnb.predict(x_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9738878143133463
# [[872  17]
#  [ 10 135]]
# 0.8881578947368421

# %%
bnb.fit(x_train,y_train)
y_pred3=bnb.predict(x_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9661508704061895
# [[885   4]
#  [ 31 114]]
# 0.9661016949152542

# %% [markdown]
# # using the TfifVectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer()

# %%
x=tfidf.fit_transform(df['transformed_text']).toarray()

# %%
x.shape
# Out:
# (5169, 6708)

# %%
y=df['target'].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y ,test_size=0.2,random_state=42)

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB()

# %%
gnb.fit(x_train,y_train)
y_pred1=gnb.predict(x_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8636363636363636
# [[772 117]
#  [ 24 121]]
# 0.5084033613445378

# %%
mnb.fit(x_train,y_train)
y_pred2=mnb.predict(x_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9613152804642167
# [[888   1]
#  [ 39 106]]
# 0.9906542056074766

# %%
bnb.fit(x_train,y_train)
y_pred3=bnb.predict(x_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9661508704061895
# [[885   4]
#  [ 31 114]]
# 0.9661016949152542

# %% [markdown]
# # looking at the precesion score we should take the tfidfvectorizer with multunomilaNB

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))
